# %% [markdown]
# <a href="https://colab.research.google.com/github/patchacha/FTW-Python-Part-1-HW/blob/master/Quiz_Exercise_PP_091920.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def Question1():
    print("What is the highest mountain in the Philippines\nA. Pulag\nB. Halcon\nC. Apo\nAnswer: ")
def Question2():
    print("\nWhat is the smallest province in the Philippines\nA. Siquijor\nB. Batanes\nC. Dinagat")
def Question3():
    print("\nWhich province in the Philippines has the largest population?\nA. Laguna\nB. Cebu\nC. Cavite")
def Question4():
    print("\nWhich city in the Philippines is the richest in terms of assets?\nA. Taguig\nB. Makati\nC. Pasig")
def Question5():
    print("\nWhat continent is the Philippines in?\nA. Europe\nB. Asia\nC. Australia")
def Question6():
    print("\nWhat religion is more prominent in the Philippines?\nA. Buddhism\nB. Muslim\nC. Roman Catholic")
def Question7():
    print("\nWhat is the Philippines' national flower?\nA. Sampaguita\nB. Waling-Waling\nC. Bougainvillea")
def Question8():
    print("\nWhat is the Philippines' national tree?\nA. Yakal\nB. Narra\nC. Molave")
def Question9():
    print("\nWhat is the Philippines' national bird?\nA. Maya\nB. Philippine Eagle\nC. Philippine Cockatoo")
def Question10():
    print("\nWhat is the Philippines' national animal?\nA. Tarsier\nB. Carabao\nC. Tamaraw")


name = input("Please enter your name: ")
print('Hello ' + str(name.title()) + '! Welcome to a Quiz about the Philippines. How well do you know our country? Type the letter of your answer.')

score = 0

answer1 = input(Question1())
if answer1 == 'C' or answer1 == 'c':
  score += 1
answer2 = input(Question2())
if answer2 == 'B' or answer2 == 'b':
  score += 1
answer3 = input(Question3())
if answer3 == 'B' or answer3 == 'b':
  score += 1
answer4 = input(Question4())
if answer4 == 'B' or answer4 == 'b':
  score += 1
answer5 = input(Question5())
if answer5 == 'B' or answer5 == 'b':
  score += 1
answer6 = input(Question6())
if answer6 == 'C' or answer6 == 'c':
  score += 1
answer7 = input(Question7())
if answer7 == 'A' or answer7 == 'a':
  score += 1
answer8 = input(Question8())
if answer8 == 'B' or answer8 == 'b':
  score += 1
answer9 = input(Question9())
if answer9 == 'B' or answer9 == 'b':
  score += 1
answer10 = input(Question10())
if answer10 == 'B' or answer10 == 'b':
  score += 1

print('\nHi %s!' % name.title())
if score >= 7:
  print("Congratulations!\nYou passed the test, you know well our beloved country.\nYour score is " + str(score) + "/10")
else:
  print("You failed.\nPlease review more about our country.\nYour score is " + str(score) + "/10")
# Out:
# Please enter your name: patricia carmela pangatungan
# Hello Patricia Carmela Pangatungan! Welcome to a Quiz about the Philippines. How well do you know our country? Type the letter of your answer.
# What is the highest mountain in the Philippines
# A. Pulag
# B. Halcon
# C. Apo
# Answer:
# c
#
# What is the smallest province in the Philippines
# A. Siquijor
# B. Batanes
# C. Dinagat
# a
#
# Which province in the Philippines has the largest population?
# A. Laguna
# B. Cebu
# C. Cavite
# b
#
# Which city in the Philippines is the richest in terms of assets?
# A. Taguig
# B. Makati
# C. Pasig
# B
#
# What continent is the Philippines in?
# A. Europe
# B. Asia
# C. Australia
# B
#
# What religion is more prominent in the Philippines?
# A. Buddhism
# B. Muslim
# C. Roman Catholic
# C
#
# What is the Philippines' national flower?
# A. Sampaguita
# B. Waling-Waling
# C. Bougainvillea
# A
#
# What is the Philippines' national tree?
# A. Yakal
# B. Narra
# C. Molave
# B
#
# ...
